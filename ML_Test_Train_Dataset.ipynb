# %% [markdown]
# #Data Spliting

# %% [markdown]
# ## Test - Train Dataset

# %%
# Importing the library
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
# File Uploading
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-270e201c-f992-4f79-8e4d-97df427620cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-270e201c-f992-4f79-8e4d-97df427620cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Data loading
dataset = pd.read_csv('/content/diabetes.csv')

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# Seprating the dataset
X = dataset.drop(columns='Outcome', axis =1)
Y = dataset['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
Standard_X = scaler.transform(X)

# %%
Standard_X.std()
# Out:
# 1.0

# %% [markdown]
# Data Spliting

# %%
# splitting of dataset
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 0.2, random_state= 2)

# %%
print(X.shape, X_train.shape, X_test.shape,  Y_train.shape, Y_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8) (614,) (154,)

# %% [markdown]
# ## Handaling Imbalnced Dataset

# %%
# importing the library
import numpy as np
import pandas as pd

# %%
# File Uploading from lacal disk
from google.colab import files
uploaded = files.upload()

# %%
# File upload from google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: how to upload google drive file in google colab using location path

drive.mount('/content/drive', force_remount=True)
file_location = '/content/drive/My Drive/Colab Notebooks/Datasets/credit_data.csv'
dataset = pd.read_csv(file_location)
# Out:
# Mounted at /content/drive

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
dataset['Amount'].value_counts()
# Out:
# Amount
# 1.00       13688
# 1.98        6044
# 0.89        4872
# 9.99        4747
# 15.00       3280
#            ...
# 62.09          1
# 552.05         1
# 1467.75        1
# 196.68         1
# 95.63          1
# Name: count, Length: 32767, dtype: int64

# %%
# THis is highly imbalnced data
dataset['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# Separating dataset

# %%
legit = dataset[dataset.Class==0]
froud = dataset[dataset.Class==1]

# %%
print(legit.shape , froud.shape)
# Out:
# (284315, 31) (492, 31)

# %% [markdown]
# Under Sampling

# %%
legit_sample = legit.sample(500)

# %%
legit_sample.shape
# Out:
# (500, 31)

# %%
# Concatenating both datasets
new_dataset = pd.concat([legit_sample, froud], axis = 0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 20906    31347.0  0.464171 -1.884287  0.759612 -0.687480 -1.825336 -0.285574
# 112024   72479.0  1.429502 -0.990271 -0.224429 -1.808740  0.770788  3.730989
# 165196  117265.0  0.170169  0.741115 -1.138815 -0.933146  1.628208 -0.223476
# 262309  160408.0  0.036735  0.551298 -1.184850 -1.731285  2.931187  3.402576
# 39477    39852.0 -1.674079 -0.732001  2.644526  1.292314 -1.374122  0.390962
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 20906  -0.278359 -0.096723  2.263746  ...  0.154549  0.097178 -0.427300
# 112024 -1.914212  1.036385 -0.316971  ...  0.376136  0.928723 -0.108174
# 165196  1.625206 -0.245352 -0.541153  ...  0.203844  0.661219 -0.421219
# 262309  0.337176  0.925322 -0.165636  ... -0.266883 -0.716064  0.105937
# 39477  -1.361366  0.905028 -0.245045  ... -0.332347 -0.449912 -0.053538
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    500
# 1    492
# Name: count, dtype: int64
